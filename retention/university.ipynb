# %%
import csv
import numpy as np
import scipy as sp
import pandas as pd
import seaborn as sns
import os
import random
import matplotlib

from matplotlib_venn import venn2
from faculty_hiring.misc.plotting import *  # Definitions for LABEL_SIZE and such
from faculty_hiring.misc.util import *
from faculty_hiring.parse import faculty_parser, institution_parser
from faculty_hiring.parse import load

# %%
df = pd.read_csv('../data/retention.csv', index_col=0)[["place", "count_ret", "count_not", "retained_frac"]]
df.head(20)
# Out:
#                                            place  count_ret  count_not  \
# 0                                Rice University         17          1
# 1            University of Massachusetts, Boston         11          1
# 2                University of Nevada, Las Vegas         10          1
# 3                              Boston University         17          2
# 4                         Santa Clara University          8          1
# 5                             University of Iowa         15          2
# 6             New Jersey Institute of Technology         22          3
# 7                       Florida State University         14          2
# 8                     University of Saskatchewan         21          3
# 9                         University of Oklahoma         13          2
# 10                      Georgia State University         13          2
# 11                              Tufts University         13          2
# 12                          University of Regina         13          2
# 13           University of Missouri, Kansas City         13          2
# 14                  University of South Carolina         19          3
# 15  City University of New York, Graduate Center          6          1
# 16                       George Mason University         35          6
# 17                         University of Arizona         11          2
# 18                           Brandeis University         10          2
# 19                               New Mexico Tech          5          1
#
#     retained_frac
# 0        0.944444
# 1        0.916667
# 2        0.909091
# 3        0.894737
# 4        0.888889
# 5        0.882353
# 6        0.880000
# 7        0.875000
# 8        0.875000
# 9        0.866667
# 10       0.866667
# 11       0.866667
# 12       0.866667
# 13       0.866667
# 14       0.863636
# 15       0.857143
# 16       0.853659
# 17       0.846154
# 18       0.833333
# 19       0.833333

# %% [markdown]
# ## Select a few institutions to highlight

# %%
df.sort_values(by = ['retained_frac'], ascending = True).head(10)
# Out:
#                                            place  count_ret  count_not  \
# 201           California Institute of Technology          1         15
# 200              Georgia Institute of Technology         25         64
# 199           University of Southern Mississippi          5         12
# 198                            Temple University          7         16
# 197           Oregon Health & Science University          4          8
# 196                           Queen's University         12         23
# 195             Virginia Commonwealth University          4          7
# 194                        University of Memphis          5          8
# 193                Claremont Graduate University          2          3
# 192  Missouri University of Science & Technology          7         10
#
#      retained_frac
# 201       0.062500
# 200       0.280899
# 199       0.294118
# 198       0.304348
# 197       0.333333
# 196       0.342857
# 195       0.363636
# 194       0.384615
# 193       0.400000
# 192       0.411765

# %%
# 1: Georgia Institute of Technology has several schools and institutes within the 
# College of Computing, three of which were created between 2011-2017 (Institute for Data & 
# High Performance Computing, Institute for People and Technology, Institute for Robotics 
# & Intelligent Machines).
#
# 2: Oregon Health & Science University has annual contracts, not typical for the TT system

# %%
# 3: Colorado School of Mines hired five new assistant professors. Two professors appeared to 
# have left, and one moved to a different university.
df[df['place'] == "Colorado School of Mines"]
# Out:
#                         place  count_ret  count_not  retained_frac
# 175  Colorado School of Mines          3          3            0.5

# %%
# 3: Two full professors retired and one moved to a different university. 
# Two professors had ambiguous titles - "Professor of Natural Science", and Dean
df[df['place'] == "Harvard University"]
# Out:
#                  place  count_ret  count_not  retained_frac
# 44  Harvard University         16          5       0.761905

# %%
# 3: One assistant professor moved to industry.
df[df['place'] == "Rice University"]
# Out:
#              place  count_ret  count_not  retained_frac
# 0  Rice University         17          1       0.944444

# %%
df.sort_values(by = ['retained_frac'], ascending = False).head(5)
# Out:
#                                  place  count_ret  count_not  retained_frac
# 0                      Rice University         17          1       0.944444
# 1  University of Massachusetts, Boston         11          1       0.916667
# 2      University of Nevada, Las Vegas         10          1       0.909091
# 3                    Boston University         17          2       0.894737
# 4               Santa Clara University          8          1       0.888889

# %%
print "Average department retention: %.4f" % np.mean(df["retained_frac"])
# Out:
# Average department retention: 0.6568
